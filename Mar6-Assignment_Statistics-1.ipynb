# %% [markdown]
# Q1. What is Statistics?

# %%
#Statistics is the science of collecting, organising and Analysing the data

# %%
Q2. Define the different types of statistics and give an example of when each type might be used.

# %%
"""
Type of stastistics:
    1. Descriptive : consists of organising and summarising the data
    2. inferential : consists of using data, that you have measured to conslusion
Descriptive example: 
    1. measure of central Tendency: mean, median, mode
    2. measure of dispersion: Variance and standard deviation
    3. Histogram, bar chart and pie chart
inferential example:
    1. Z-Test
    2. T-test
    3. Hypothesis test
    4. P Value and Significance   
"""
# Out:
# '\nType of stastistics:\n    1. Descriptive : consists of organising and summarising the data\n    2. inferential : consists of using data, that you have measured to conslusion\nDescriptive example: \n    1. measure of central Tendency: mean, median, mode\n    2. measure of dispersion: Variance and standard deviation\n    3. Histogram, bar chart and pie chart\ninferential example:\n    1. Z-Test\n    2. T-test\n    3. Hypothesis test\n    4. P Value and Significance   \n'

# %%
Q3. What are the different types of data and how do they differ from each other? Provide an example of
each type of data.

# %%
from IPython import display
display.Image("Types of data.png")

# %% [markdown]
# Q4. Categorise the following datasets with respect to quantitative and qualitative data types:
# (i) Grading in exam: A+, A, B+, B, C+, C, D, E
# (ii) Colour of mangoes: yellow, green, orange, red
# (iii) Height data of a class: [178.9, 179, 179.5, 176, 177.2, 178.3, 175.8,...]
# (iv) Number of mangoes exported by a farm: [500, 600, 478, 672, ...]

# %%
#Qualitative data set: (i) and (ii)
#Quantitative data set (ii) aND (iv)

# %% [markdown]
# Q5. Explain the concept of levels of measurement and give an example of a variable for each level.

# %%
"""
1. Nominal cale data:
    Qualitative/Categirical varioable
    Order doen not matter
    ex: color, gender, labels
2. ordinal scale data:
    Ranking and order matters
    difference can not be measured
    ex: Education Qualification like, PHD, Mtech, BTech, Bsc, BA
3. interval scale data:
    Rank and order matters
    Difference can be measured (excluding ratios)
    Does not have "0" starting value
    Example - Temperature: 100F,70F,30F,60F
    (ratio doesn't have any significance)    
4. ratio scale data:
    Rank and order matters
    Difference and ratio can be measured
    can have "0" starting value
    ex: marks in a class: 0, 20,50,100,99,54,32   
"""

# %%
Q6. Why is it important to understand the level of measurement when analyzing data? Provide an
example to illustrate your answer.

# %%
"""
Learning about the four levels of measurement allows statisticians and analysts to more efficiently plan for research and present their findings
"""
"""
Gender is an example of a nominal variable because the categories (woman, man, transgender, non-binary, etc.) cannot be ordered from high to low. 
Olympic medals are an example of an ordinal variable because the categories (gold, silver, bronze) can be ordered from high to low.
"""
# Out:
# '\nGender is an example of a nominal variable because the categories (woman, man, transgender, non-binary, etc.) cannot be ordered from high to low. \nOlympic medals are an example of an ordinal variable because the categories (gold, silver, bronze) can be ordered from high to low.\n'

# %%
Q7. How nominal data type is different from ordinal data type.

# %%
#Ranking and order is matter is ordinal data, where as order is not important in nominal data

# %%
Q8. Which type of plot can be used to display data in terms of range?

# %%
#A histogram is a graphical representation of data points organized into user-specified ranges.

# %%
Q9. Describe the difference between descriptive and inferential statistics. Give an example of each
type of statistics and explain how they are used.

# %%
"""
Descriptive consists of organising and summarising the data, where as inferential consists of using data, that you have measured to conslusion.
Descriptive example: 
    1. measure of central Tendency: mean, median, mode
    2. measure of dispersion: Variance and standard deviation
    3. Histogram, bar chart and pie chart
inferential example:
    1. Z-Test
    2. T-test
    3. Hypothesis test
    4. P Value and Significance
"""
# Out:
# '\nDescriptive consists of organising and summarising the data, where as inferential consists of using data, that you have measured to conslusion.\nDescriptive example: \n    1. measure of central Tendency: mean, median, mode\n    2. measure of dispersion: Variance and standard deviation\n    3. Histogram, bar chart and pie chart\ninferential example:\n    1. Z-Test\n    2. T-test\n    3. Hypothesis test\n    4. P Value and Significance\n'

# %%
Q10. What are some common measures of central tendency and variability used in statistics? Explain
how each measure can be used to describe a dataset.

# %%
"""
Measures of central tendency tell us what is common or typical about our variable. 
Three measures of central tendency are the mode, the median and the mean

The mode is used almost exclusively with nominal-level data, as it is the only measure of central tendency available for such variables. 
The median is used with ordinal-level data or when an interval/ratio-level variable is skewed. 
The mean can only be used with interval/ratio level data.
"""

"""
Measures of variability are numbers that describe how much variation or diversity there is in a distribution.
Four measures of variability are the range (the difference between the larges and smallest observations), the interquartile range (the difference between the 75th and 25th percentiles) the variance and the standard deviation.
The variance and standard deviation are two closely related measures of variability for interval/ratio-level variables that increase or decrease depending on how closely the observations are clustered around the mean.
"""
# Out:
# '\nMeasures of variability are numbers that describe how much variation or diversity there is in a distribution.\nFour measures of variability are the range (the difference between the larges and smallest observations), the interquartile range (the difference between the 75th and 25th percentiles) the variance and the standard deviation.\nThe variance and standard deviation are two closely related measures of variability for interval/ratio-level variables that increase or decrease depending on how closely the observations are clustered around the mean.\n'
